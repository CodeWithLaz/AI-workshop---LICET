# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeWithLaz/AI-workshop---LICET/blob/main/day3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
# !python -m spacy download en_core_web_md
nlp = spacy.load("en_core_web_md")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 30.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
doc = nlp(u'The quick brown for jumped over the lazy dogs')
doc.vector
# Out:
# array([-7.20823348e-01,  2.50588916e-02, -8.99682343e-02,  2.16201041e-02,
#         5.11989184e-03, -8.48394334e-02, -3.46056670e-02, -9.23808888e-02,
#         9.58159864e-02,  1.77782011e+00, -4.12166640e-02,  5.50666777e-03,
#        -4.24046256e-02,  2.30645556e-02, -5.38855568e-02,  1.26736343e-01,
#        -9.19329002e-02,  1.17073667e+00, -1.31303355e-01, -2.18191251e-01,
#        -8.92397687e-02,  6.16097786e-02,  4.69475538e-02, -2.86513329e-01,
#        -1.32850021e-01, -1.27459675e-01, -2.90766521e-03, -7.52422661e-02,
#        -2.32016742e-02, -2.41016656e-01, -2.61264443e-01,  2.24324882e-01,
#         1.44761220e-01, -6.24811240e-02,  1.96125329e-01,  6.33667856e-02,
#        -1.48164108e-01, -7.71666765e-02, -1.57655537e-01,  8.34699944e-02,
#         9.63742584e-02,  1.20254435e-01, -4.89800461e-02, -4.03230004e-02,
#         2.00128764e-01, -7.29341134e-02, -9.62548926e-02, -1.16184436e-01,
# ...

# %%
tokens = nlp(u'lion cat pet')
tokens
# Out:
# lion cat pet

# %%
for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))
# Out:
# lion lion 1.0
# lion cat 0.31077107787132263
# lion pet 0.31077107787132263
# cat lion 0.31077107787132263
# cat cat 1.0
# cat pet 1.0000001192092896
# pet lion 0.31077107787132263
# pet cat 1.0000001192092896
# pet pet 1.0

# %%
nlp(u'lion').similarity(nlp(u'dandelion'))
# Out:
# 0.344340443611145

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
a ='This is a good movie'
sid.polarity_scores(a)
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}

# %%
b ='This was the best, most awesome movie EVER MADE!!!'
sid.polarity_scores(b)
# Out:
# {'neg': 0.0, 'neu': 0.425, 'pos': 0.575, 'compound': 0.8877}

# %%
c ='This was the worst film to ever disgrace the screen'
sid.polarity_scores(c)
# Out:
# {'neg': 0.477, 'neu': 0.523, 'pos': 0.0, 'compound': -0.8074}

# %%
for i,lb
# Out:
#   File "/tmp/ipython-input-1193845345.py", line 1
#     for i,lb
#             ^
# SyntaxError: invalid syntax
